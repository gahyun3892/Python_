# %%
import matplotlib.pyplot as plt
a=[10, -20, 30, 40]
c=[-30,20,50,10]
b=['kor', 'eng', 'math', 'info']
plt.bar(b,a, color = 'red')
plt.ylabel('jumsu')
plt.xlabel('subject')
plt.title('Score')
plt.legend('value')
